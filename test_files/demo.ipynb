# %%
# 导入python包

from datavalidator.visualization.data_visualization import data_visualize
import pandas as pd

# %%
# 导入数据集

df=pd.read_csv('train.csv')
df2=pd.read_csv('test.csv')

# %%
# 调用可视化函数

data_visualize([{'name': 'titanic-train', 'table': df}, {'name': 'titanic-test', 'table': df2}])
